# %% [markdown]
# # [DeepSphere]: a spherical convolutional neural network
# [DeepSphere]: https://github.com/SwissDataScienceCenter/DeepSphere
#
# [Nathanaël Perraudin](https://perraudin.info), [Michaël Defferrard](http://deff.ch), Tomasz Kacprzak, Raphael Sgier
#
# # Demo: whole sphere classification

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import shutil

# Run on CPU.
os.environ["CUDA_VISIBLE_DEVICES"] = ""

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import healpy as hp
import tensorflow as tf

from deepsphere import models, experiment_helper, plot
from deepsphere.data import LabeledDataset

# %%
plt.rcParams['figure.figsize'] = (17, 5)

# %%
EXP_NAME = 'whole_sphere'

# %% [markdown]
# ## 1 Data loading
#
# The data consists of a toy dataset that is sufficiently small to have fun with. It is made of 200 maps of size `NSIDE=64` splitted into 2 classes.
#
# The maps contain a Gaussian random field realisations produced with Synfast function from Healpy package.
# The input power spectra were taken from LambdaCDM model with two sets of parameters.
# These maps are not realistic cosmological mass maps, just a toy dataset.
# We downsampled them to `Nside=64` in order to make the processing faster.

# %%
data = np.load('data/maps_downsampled_64.npz')
assert(len(data['class1']) == len(data['class2']))
nclass = len(data['class1'])

# %% [markdown]
# Let us plot a map of each class. It is not simple to visually catch the differences.

# %%
cmin = min(np.min(data['class1']), np.min(data['class2']))
cmax = max(np.max(data['class1']), np.max(data['class2']))
cm = plt.cm.RdBu_r
cm.set_under('w')
hp.mollview(data['class1'][0], title='class 1', nest=True, cmap=cm, min=cmin, max=cmax)
hp.mollview(data['class2'][0], title='class 2', nest=True, cmap=cm, min=cmin, max=cmax)

# %% [markdown]
# However, those maps have different Power Spectral Densities PSD.

# %%
sample_psd_class1 = np.empty((nclass, 192))
sample_psd_class2 = np.empty((nclass, 192))

for i in range(nclass):
    sample_psd_class1[i] = experiment_helper.psd(data['class1'][i])
    sample_psd_class2[i] = experiment_helper.psd(data['class2'][i])

# %%
ell = np.arange(sample_psd_class1.shape[1])
plot.plot_with_std(ell, sample_psd_class1*ell*(ell+1), label='class 1, Omega_matter=0.3, mean', color='b')
plot.plot_with_std(ell,sample_psd_class2*ell*(ell+1), label='class 2, Omega_matter=0.5, mean', color='r')
plt.legend(fontsize=16);
plt.xlim([10, np.max(ell)])
plt.ylim([1e-6, 1e-3])
# plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\ell$: spherical harmonic index', fontsize=18)
plt.ylabel('$C_\ell \cdot \ell \cdot (\ell+1)$', fontsize=18)
plt.title('Power Spectrum Density, 3-arcmin smoothing, noiseless, Nside=1024', fontsize=18);

# %% [markdown]
# ## 2 Data preparation
#
# Let us split the data into training and testing sets. The raw data is stored into `x_raw` and the power spectrum densities into `x_psd`.

# %%
# Normalize and transform the data, i.e. extract features.
x_raw = np.vstack((data['class1'], data['class2']))
x_raw = x_raw / np.mean(x_raw**2) # Apply some normalization (We do not want to affect the mean)
x_psd = preprocessing.scale(np.vstack((sample_psd_class1, sample_psd_class2)))

# Create the label vector
labels = np.zeros([x_raw.shape[0]], dtype=int)
labels[nclass:] = 1

# Random train / test split
ntrain = 150
ret = train_test_split(x_raw, x_psd, labels, test_size=2*nclass-ntrain, shuffle=True)
x_raw_train, x_raw_test, x_psd_train, x_psd_test, labels_train, labels_test = ret

print('Class 1 VS class 2')
print('  Training set: {} / {}'.format(np.sum(labels_train==0), np.sum(labels_train==1)))
print('  Test set: {} / {}'.format(np.sum(labels_test==0), np.sum(labels_test==1)))
# Out:
# Class 1 VS class 2
#   Training set: 82 / 68
#   Test set: 18 / 32

# %% [markdown]
# ## 3 Classification using SVM
#
# As a baseline, let us classify our data using an SVM classifier.
#
# * An SVM based on the raw feature cannot discriminate the data because the dimensionality of the data is too large.
# * We however observe that the PSD features are linearly separable.

# %%
clf = SVC(kernel='rbf')
clf.fit(x_raw_train, labels_train) 

e_train = experiment_helper.model_error(clf, x_raw_train, labels_train)
e_test = experiment_helper.model_error(clf, x_raw_test, labels_test)
print('The training error is: {}%'.format(e_train*100))
print('The testing error is: {}%'.format(e_test*100))
# Out:
# /home/rno/VirtualEnvs/deepsphere-fem/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# The training error is: 0.0%
# The testing error is: 64.0%

# %%
clf = SVC(kernel='linear')
clf.fit(x_psd_train, labels_train) 

e_train = experiment_helper.model_error(clf, x_psd_train, labels_train)
e_test = experiment_helper.model_error(clf, x_psd_test, labels_test)
print('The training error is: {}%'.format(e_train*100))
print('The testing error is: {}%'.format(e_test*100))
# Out:
# The training error is: 0.0%
# The testing error is: 0.0%

# %% [markdown]
# ## 4 Classification using DeepSphere
#
# Let us now classify our data using a spherical convolutional neural network.
#
# Three types of architectures are suitable for this task:
# 1. Classic CNN: the classic ConvNet composed of some convolutional layers followed by some fully connected layers.
# 2. Stat layer: a statistical layer, which computes some statistics over the pixels, is inserted between the convolutional and fully connected layers. The role of this added layer is make the prediction invariant to the position of the pixels on the sphere.
# 3. Fully convolutional: the fully connected layers are removed and the network outputs many predictions at various spatial locations that are then averaged.
#
# On this simple task, all architectures can reach 100% test accuracy. Nevertheless, the number of parameters to learn decreases and training converges faster. A fully convolutional network is much faster and efficient in terms of parameters. It does however assume that all pixels have the same importance and that their location does not matter. While that is true for cosmological applications, it may not for others.

# %%
params = dict()
params['dir_name'] = EXP_NAME

# Types of layers.
params['conv'] = 'chebyshev5'  # Graph convolution: chebyshev5 or monomials.
params['pool'] = 'max'  # Pooling: max or average.
params['activation'] = 'relu'  # Non-linearity: relu, elu, leaky_relu, softmax, tanh, etc.
params['statistics'] = None  # Statistics (for invariance): None, mean, var, meanvar, hist.

# Architecture.
architecture = 'fully_convolutional'

if architecture == 'classic_cnn':
    params['statistics'] = None
    params['nsides'] = [64, 32, 16, 16]  # Pooling: number of pixels per layer.
    params['F'] = [5, 5, 5]  # Graph convolutional layers: number of feature maps.
    params['M'] = [50, 2]  # Fully connected layers: output dimensionalities.

elif architecture == 'stat_layer':
    params['statistics'] = 'meanvar'
    params['nsides'] = [64, 32, 16, 16]  # Pooling: number of pixels per layer.
    params['F'] = [5, 5, 5]  # Graph convolutional layers: number of feature maps.
    params['M'] = [50, 2]  # Fully connected layers: output dimensionalities.

elif architecture == 'fully_convolutional':
    params['statistics'] = 'mean'
    params['nsides'] = [64, 32, 16, 8, 8]
    params['F'] = [5, 5, 5, 2]
    params['M'] = []

params['K'] = [10] * len(params['F'])  # Polynomial orders.
params['batch_norm'] = [True] * len(params['F'])  # Batch normalization.

# Regularization.
params['regularization'] = 0  # Amount of L2 regularization over the weights (will be divided by the number of weights).
params['dropout'] = 0.5  # Percentage of neurons to keep.

# Training.
params['num_epochs'] = 12  # Number of passes through the training data.
params['batch_size'] = 16  # Number of samples per training batch. Should be a power of 2 for greater speed.
params['eval_frequency'] = 15  # Frequency of model evaluations during training (influence training time).
params['scheduler'] = lambda step: 1e-1  # Constant learning rate.
params['optimizer'] = lambda lr: tf.train.GradientDescentOptimizer(lr)
#params['optimizer'] = lambda lr: tf.train.MomentumOptimizer(lr, momentum=0.5)
#params['optimizer'] = lambda lr: tf.train.AdamOptimizer(lr, beta1=0.9, beta2=0.999, epsilon=1e-8)

# %%
model = models.deepsphere(**params)
# Out:
# NN architecture
#   input: M_0 = 49152
#   layer 1: cgconv1
#     representation: M_0 * F_1 / p_1 = 49152 * 5 / 4 = 61440
#     weights: F_0 * F_1 * K_1 = 1 * 5 * 10 = 50
#     biases: F_1 = 5
#     batch normalization
#   layer 2: cgconv2
#     representation: M_1 * F_2 / p_2 = 12288 * 5 / 4 = 15360
#     weights: F_1 * F_2 * K_2 = 5 * 5 * 10 = 250
#     biases: F_2 = 5
#     batch normalization
#   layer 3: cgconv3
#     representation: M_2 * F_3 / p_3 = 3072 * 5 / 4 = 3840
#     weights: F_2 * F_3 * K_3 = 5 * 5 * 10 = 250
#     biases: F_3 = 5
#     batch normalization
#   layer 4: cgconv4
#     representation: M_3 * F_4 / p_4 = 768 * 2 / 1 = 1536
#     weights: F_3 * F_4 * K_4 = 5 * 2 * 10 = 100
#     batch normalization
#   Statistical layer: mean
#     representation: 1 * 2 = 2
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:236: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_initializable_iterator(dataset)`.
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:242: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:244: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:773: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:589: The name tf.sparse_reorder is deprecated. Please use tf.sparse.reorder instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:598: The name tf.sparse_tensor_dense_matmul is deprecated. Please use tf.sparse.sparse_dense_matmul instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:349: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:353: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:752: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /home/rno/VirtualEnvs/deepsphere-fem/lib/python3.7/site-packages/tensorflow_core/python/layers/normalization.py:327: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:701: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:295: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:304: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:327: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:327: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:253: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:256: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:257: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.

# %%
# Cleanup before running again.
shutil.rmtree('summaries/{}/'.format(EXP_NAME), ignore_errors=True)
shutil.rmtree('checkpoints/{}/'.format(EXP_NAME), ignore_errors=True)

# %%
training = LabeledDataset(x_raw_train, labels_train)
testing = LabeledDataset(x_raw_test, labels_test)

# %%
accuracy_validation, loss_validation, loss_training, t_step = model.fit(training, testing)
# Out:
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:137: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:141: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# step 1
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 2
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 3
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 4
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 5
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 6
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 7
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 8
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 9
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 10
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 11
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 12
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 13
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 14
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 15
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 15 / 112 (epoch 1.60 / 12):
#   learning_rate = 1.00e-01, training loss = 9.08e-02
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.26543695
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.086457394
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.41050857
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.10711643
#   validation accuracy: 80.00 (40 / 50), f1 (weighted): 77.51, loss: 2.78e-01
#   CPU time: 49s, wall time: 22s
# WARNING:tensorflow:From /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/models.py:198: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# step 16
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 17
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 18
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 19
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 20
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 21
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 22
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 23
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 24
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 25
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 26
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 27
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 28
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 29
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 30
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 30 / 112 (epoch 3.20 / 12):
#   learning_rate = 1.00e-01, training loss = 3.09e-02
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0137726115
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.011056414
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.022852194
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0043168007
#   validation accuracy: 100.00 (50 / 50), f1 (weighted): 100.00, loss: 1.66e-02
#   CPU time: 98s, wall time: 42s
# step 31
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 32
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 33
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 34
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 35
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 36
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 37
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 38
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 39
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 40
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 41
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 42
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 43
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 44
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 45
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 45 / 112 (epoch 4.80 / 12):
#   learning_rate = 1.00e-01, training loss = 5.34e-02
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.006459087
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.010114794
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0068112686
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.00059591094
#   validation accuracy: 100.00 (50 / 50), f1 (weighted): 100.00, loss: 7.67e-03
#   CPU time: 147s, wall time: 61s
# step 46
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 47
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 48
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 49
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 50
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 51
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 52
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 53
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 54
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 55
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 56
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 57
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 58
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 59
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 60
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 60 / 112 (epoch 6.40 / 12):
#   learning_rate = 1.00e-01, training loss = 4.64e-03
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0031943063
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0042484147
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0045108525
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.00057744485
#   validation accuracy: 100.00 (50 / 50), f1 (weighted): 100.00, loss: 4.01e-03
#   CPU time: 195s, wall time: 79s
# step 61
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 62
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 63
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 64
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 65
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 66
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 67
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 68
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 69
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 70
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 71
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 72
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 73
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 74
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 75
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 75 / 112 (epoch 8.00 / 12):
#   learning_rate = 1.00e-01, training loss = 1.32e-02
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0018907886
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0022519024
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0032167044
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.00045107014
#   validation accuracy: 100.00 (50 / 50), f1 (weighted): 100.00, loss: 2.50e-03
#   CPU time: 243s, wall time: 96s
# step 76
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 77
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 78
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 79
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 80
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 81
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 82
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 83
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 84
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 85
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 86
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 87
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 88
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 89
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 90
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 90 / 112 (epoch 9.60 / 12):
#   learning_rate = 1.00e-01, training loss = 2.59e-03
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0018612294
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0028375804
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.00242058
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.00025384084
#   validation accuracy: 100.00 (50 / 50), f1 (weighted): 100.00, loss: 2.36e-03
#   CPU time: 291s, wall time: 114s
# WARNING:tensorflow:From /home/rno/VirtualEnvs/deepsphere-fem/lib/python3.7/site-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# step 91
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 92
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 93
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 94
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 95
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 96
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 97
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 98
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 99
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 100
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 101
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 102
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 103
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 104
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 105
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 105 / 112 (epoch 11.20 / 12):
#   learning_rate = 1.00e-01, training loss = 6.37e-03
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0011276528
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0015215026
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0018333141
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.00022859551
#   validation accuracy: 100.00 (50 / 50), f1 (weighted): 100.00, loss: 1.51e-03
#   CPU time: 340s, wall time: 133s
# step 106
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 107
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 108
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 109
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 110
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 111
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 112
# ops : Tensor("training/control:0", shape=(), dtype=float32) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds : (16, 49152) (16,)
# step 112 / 112 (epoch 11.95 / 12):
#   learning_rate = 1.00e-01, training loss = 1.34e-02
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0010126366
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.0009594585
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.002312399
# ops : Tensor("prediction/ArgMax:0", shape=(16,), dtype=int64) Tensor("loss/add:0", shape=(), dtype=float32)
# feeds :  (16, 49152) (16,)
# batch_loss :  0.00034349796
#   validation accuracy: 100.00 (50 / 50), f1 (weighted): 100.00, loss: 1.48e-03
#   CPU time: 364s, wall time: 143s
# validation accuracy: best = 100.00, mean = 97.50

# %%
plot.plot_loss(loss_training, loss_validation, t_step, params['eval_frequency'])

# %%
error_train = experiment_helper.model_error(model, x_raw_train, labels_train)
error_test = experiment_helper.model_error(model, x_raw_test, labels_test)
print('The training error is: {:.2%}'.format(error_train))
print('The testing error is: {:.2%}'.format(error_test))
# Out:
# /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/../checkpoints/whole_sphere
# INFO:tensorflow:Restoring parameters from /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/../checkpoints/whole_sphere/model-112
# /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/../checkpoints/whole_sphere
# INFO:tensorflow:Restoring parameters from /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/../checkpoints/whole_sphere/model-112
# The training error is: 0.00%
# The testing error is: 0.00%

# %% [markdown]
# ## 5 Filters visualization
#
# The package offers a few different visualizations for the learned filters. First we can simply look at the Chebyshef coefficients. This visualization is not very interpretable for human, but can help for debugging problems related to optimization.

# %%
layer=2
model.plot_chebyshev_coeffs(layer)
# Out:
# /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/../checkpoints/whole_sphere
# INFO:tensorflow:Restoring parameters from /home/rno/EPFL/lts2/deepsphere-fem/deepsphere/../checkpoints/whole_sphere/model-112

# %% [markdown]
# We observe the Chebyshef polynomial, i.e the filters in the graph spectral domain. This visuallization can help to understand wich graph frequencies are picked by the filtering operation. It mostly interpretable by the people for the graph signal processing community.

# %%
model.plot_filters_spectral(layer);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-85a6b69d69d6> in <module>
# ----> 1 model.plot_filters_spectral(layer);
#
# ~/EPFL/lts2/deepsphere-fem/deepsphere/models.py in plot_filters_spectral(self, layer, ind_in, ind_out, ax, **kwargs)
#     951         import matplotlib.pyplot as plt
#     952
# --> 953         filters = self.get_gsp_filters(layer,  ind_in=ind_in, ind_out=ind_out)
#     954
#     955         if ax is None:
#
# ~/EPFL/lts2/deepsphere-fem/deepsphere/models.py in get_gsp_filters(self, layer, ind_in, ind_out)
#     930         ind_out : index(es) of the output filter(s) (default None, all the filters)
#     931         """
# --> 932         from pygsp import filters
#     933
#     934         trained_weights = self.get_filter_coeffs(layer, ind_in, ind_out)
#
# ModuleNotFoundError: No module named 'pygsp'

# %% [markdown]
# Here comes one of the most human friendly representation of the filters. It consists the section of the filters "projected" on the sphere. Because of the irregularity of the healpix sampling, this representation of the filters may not look very smooth.

# %%
mpl.rcParams.update({'font.size': 16})
model.plot_filters_section(layer, title='');

# %% [markdown]
# Eventually, we can simply look at the filters on sphere. This representation clearly displays the sampling artifacts.

# %%
plt.rcParams['figure.figsize'] = (10, 10)
model.plot_filters_gnomonic(layer, title='')
